# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np
import pandas as pd
from scipy import stats

# %%
# SPARCS data 
sparcs_df_14 = pd.read_csv("NYSDOH_Hospital_Inpatient_Discharges_SPARCS_De-Identified_2014.csv")
sparcs_df_13 = pd.read_csv("NYSDOH_Hospital_Inpatient_Discharges_SPARCS_De-Identified_2013.csv")
sparcs_df_12 = pd.read_csv("NYSDOH_Hospital_Inpatient_Discharges_SPARCS_De-Identified_2012.csv")
sparcs_df_11 = pd.read_csv("NYSDOH_Hospital_Inpatient_Discharges_SPARCS_De-Identified_2011.csv")
sparcs_df_10 = pd.read_csv("NYSDOH_Hospital_Inpatient_Discharges_SPARCS_De-Identified_2010.csv")
sparcs_df_09 = pd.read_csv("NYSDOH_Hospital_Inpatient_Discharges_SPARCS_De-Identified_2009.csv")
# Out:
# C:\Users\samko\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\samko\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\samko\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (6,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#merge years into one large data set
frames = [sparcs_df_14, sparcs_df_13, sparcs_df_12, sparcs_df_11, sparcs_df_10, sparcs_df_09]
sparcs_df = pd.concat(frames)

# %%
del sparcs_df_14
del sparcs_df_13
del sparcs_df_12
del sparcs_df_11
del sparcs_df_10
del sparcs_df_09
del frames

# %%
sparcs_df.to_csv("merged_data.csv")

# %%
sparcs_df = pd.read_csv("merged_data.csv")
# Out:
# C:\Users\samko\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (24,36,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
cols_to_drop = ['APR DRG Code', 'APR MDC Code',
       'APR MDC Description', 'APR Medical Surgical Description',
       'APR Severity of Illness Description', 'Abortion Edit Indicator',
       'Attending Provider License Number', 'Birth Weight',
       'CCS Diagnosis Code', 'CCS Diagnosis Description', 'CCS Procedure Code','Emergency Department Indicator',
       'Operating Certificate Number', 'Operating Provider License Number',
       'Other Provider License Number', 'Patient Disposition','Payment Typology 2', 'Payment Typology 3',
       'Permanent Facility Id']

# %%
# delete columns that aren't used
# df.drop(['B', 'C'], axis=1)

for col in cols_to_drop: 
    sparcs_df.drop(col, 1, inplace=True)

# %%
sparcs_df.to_csv("filtered_merged_data.csv")

# %%
#df w/ procedure names w/  counts to find quantify number of caths
proc_df = sparcs_df.groupby("CCS Procedure Description").size().sort_values(
    ascending=False).reset_index(
    name="procedure counts")

#CSV of procedure names w/ counts
proc_df.to_csv("procedure_counts.csv")

# %% [markdown]
# # Procedures of interest:
# DX CARDIAC CATHETERIZTN = 180058
#
#
# PERC TRANSLUM COR ANGIO = 206731

# %%
# df of all indivitual caths performed
cath_df = sparcs_df[(sparcs_df["CCS Procedure Description"].str.upper() == "DX CARDIAC CATHETERIZTN") |
                   (sparcs_df["CCS Procedure Description"].str.upper() == "PERC TRANSLUM COR ANGIO")]

# %%
# upper case APR column for sorting purposes
cath_df["APR DRG Description"] = cath_df["APR DRG Description"].str.upper()
# Out:
# C:\Users\samko\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
# df of cath counts per diagnosis
dx_cath_df = cath_df.groupby("APR DRG Description").size().sort_values(
    ascending=False).reset_index(
    name="cath counts per dx")

# CSV of cath counts per diagnosis
dx_cath_df.to_csv("cath_counts_per_dx.csv")

# %% [markdown]
# # Relevant Diagnoses
#
#
# PERCUTANEOUS CARDIOVASCULAR PROCEDURES W/O AMI
#
# PERCUTANEOUS CORONARY INTERVENTION W/O AMI
#
# CARDIAC CATHETERIZATION FOR ISCHEMIC HEART DISEASE
#
# PERCUTANEOUS CORONARY INTERVENTION W AMI
#
# PERCUTANEOUS CARDIOVASCULAR PROCEDURES W AMI
#
# CARDIAC CATHETERIZATION FOR OTHER NON-CORONARY CONDITIONS
#
# ACUTE MYOCARDIAL INFARCTION
#
# CARDIAC CATHETERIZATION W CIRC DISORD EXC ISCHEMIC HEART DISEASE
#
# CARDIAC CATHETERIZATION FOR CORONARY ARTERY DISEASE

# %%
# Dx of CAD
CAD_dx_list = ["PERCUTANEOUS CARDIOVASCULAR PROCEDURES W/O AMI",
"PERCUTANEOUS CORONARY INTERVENTION W/O AMI",
"CARDIAC CATHETERIZATION FOR ISCHEMIC HEART DISEASE",
"PERCUTANEOUS CORONARY INTERVENTION W AMI",
"PERCUTANEOUS CARDIOVASCULAR PROCEDURES W AMI",
#"CARDIAC CATHETERIZATION FOR OTHER NON-CORONARY CONDITIONS",
"ACUTE MYOCARDIAL INFARCTION",
"CARDIAC CATHETERIZATION W CIRC DISORD EXC ISCHEMIC HEART DISEASE",
"CARDIAC CATHETERIZATION FOR CORONARY ARTERY DISEASE"]

# %%
# subset of dataset where caths were done for CAD; dataset of interest for our analysis
CAD_cath_df = cath_df[cath_df["APR DRG Description"].isin(CAD_dx_list)]

# %%
hospital_df = pd.DataFrame(CAD_cath_df["Facility Name"].unique())
hospital_df = hospital_df.rename(columns={0 : "hospitals"}).sort_values(by="hospitals").reset_index(drop=True)
hospital_df.to_csv("hospital_list.csv")

# %% [markdown]
# Get cath df
# Filter based off dx's of interest
# Get hospital list who did cath for dx's group of interest
# Label teaching vs non-teaching
# Then compare outcomes
#     * stratify for illness severity
#     * stratify for diagnostic group

# %%
# caths_per_site_df
caths_per_site_df = CAD_cath_df.groupby("Facility Name").size().sort_values(
    ascending=False).reset_index(
    name="cath counts per hosp")

# %%
caths_per_site_df.to_csv('caths_per_hospital.csv')

# %%
# import fellow sites 
fellow_sites_df = pd.read_csv("fellowship_locations.csv")

# %%
fellow_sites_df
# Out:
#                                              Hospitals  Fellows
# 0                       Albany Medical Center Hospital        1
# 1                             Albany Memorial Hospital        1
# 2                           Arnot Ogden Medical Center        0
# 3                             Bellevue Hospital Center        1
# 4                                 Benedictine Hospital        0
# 5             Beth Israel Medical Center/Petrie Campus        1
# 6    Bronx-Lebanon Hospital Center - Concourse Divi...        0
# 7                    Brookdale Hospital Medical Center        1
# 8      Brookhaven Memorial Hospital Medical Center Inc        0
# 9           Brooklyn Hospital Center - Downtown Campus        1
# 10                            Buffalo General Hospital        1
# 11                     Cayuga Medical Center at Ithaca        0
# 12   Champlain Valley Physicians Hospital Medical C...        0
# 13                 Clifton Springs Hospital and Clinic        0
# 14                          Columbia Memorial Hospital        0
# 15                               Coney Island Hospital        0
# 16                                     Crouse Hospital        0
# 17                           Degraff Memorial Hospital        0
# 18                                      Ellis Hospital        0
# 19                            Elmhurst Hospital Center        1
# 20                          Erie County Medical Center        0
# 21                               F F Thompson Hospital        0
# 22        Faxton-St Lukes Healthcare St Lukes Division        0
# 23                    Flushing Hospital Medical Center        0
# 24                               Forest Hills Hospital        0
# 25                                   Franklin Hospital        0
# 26                             Geneva General Hospital        0
# 27                                Glens Falls Hospital        0
# 28              Good Samaritan Hospital Medical Center        0
# 29                  Good Samaritan Hospital of Suffern        0
# ..                                                 ...      ...
# 119  St Lukes Roosevelt Hospital - St Lukes Hospita...        1
# 120  St Lukes Roosevelt Hospital Center - Roosevelt...        0
# 121                                 St Peters Hospital        0
# 122              St. Luke's Cornwall Hospital/Cornwall        0
# 123                              St. Mary's Healthcare        0
# 124                Staten Island University Hosp-North        1
# 125                Staten Island University Hosp-South        1
# 126                           Strong Memorial Hospital        1
# 127                                   Syosset Hospital        0
# 128                    The Unity Hospital of Rochester        0
# 129  The University of Vermont Health Network - Cha...        0
# 130   UPSTATE University Hospital at Community General        0
# 131  United Health Services Hospitals Inc. - Bingha...        0
# 132  United Health Services Hospitals Inc. - Wilson...        0
# 133  United Memorial Medical Center North Street Ca...        0
# 134                                University Hospital        1
# 135     University Hospital SUNY Health Science Center        1
# 136                    University Hospital of Brooklyn        1
# 137                     Vassar Brothers Medical Center        0
# 138                         Westchester Medical Center        1
# 139                       White Plains Hospital Center        0
# 140                       Winthrop-University Hospital        1
# 141                      Woman's Christian Association        0
# 142            Woodhull Medical & Mental Health Center        0
# 143                     Wyckoff Heights Medical Center        0
# 144                       White Plains Hospital Center        0
# 145                       Winthrop-University Hospital        0
# 146                      Woman's Christian Association        0
# 147            Woodhull Medical & Mental Health Center        0
# 148                     Wyckoff Heights Medical Center        0
#
# [149 rows x 2 columns]

# %%
hospital_df.shape
# Out:
# (143, 1)

# %%
fellow_sites_df.shape
# Out:
# (149, 2)

# %%
fellow_sites_df[fellow_sites_df['Hospitals'].isin(hospital_df['hospitals'])]
# Out:
#                                              Hospitals  Fellows
# 0                       Albany Medical Center Hospital        1
# 1                             Albany Memorial Hospital        1
# 2                           Arnot Ogden Medical Center        0
# 3                             Bellevue Hospital Center        1
# 4                                 Benedictine Hospital        0
# 5             Beth Israel Medical Center/Petrie Campus        1
# 6    Bronx-Lebanon Hospital Center - Concourse Divi...        0
# 7                    Brookdale Hospital Medical Center        1
# 8      Brookhaven Memorial Hospital Medical Center Inc        0
# 9           Brooklyn Hospital Center - Downtown Campus        1
# 10                            Buffalo General Hospital        1
# 11                     Cayuga Medical Center at Ithaca        0
# 12   Champlain Valley Physicians Hospital Medical C...        0
# 13                 Clifton Springs Hospital and Clinic        0
# 14                          Columbia Memorial Hospital        0
# 15                               Coney Island Hospital        0
# 16                                     Crouse Hospital        0
# 17                           Degraff Memorial Hospital        0
# 18                                      Ellis Hospital        0
# 19                            Elmhurst Hospital Center        1
# 20                          Erie County Medical Center        0
# 21                               F F Thompson Hospital        0
# 22        Faxton-St Lukes Healthcare St Lukes Division        0
# 23                    Flushing Hospital Medical Center        0
# 24                               Forest Hills Hospital        0
# 25                                   Franklin Hospital        0
# 26                             Geneva General Hospital        0
# 27                                Glens Falls Hospital        0
# 28              Good Samaritan Hospital Medical Center        0
# 29                  Good Samaritan Hospital of Suffern        0
# ..                                                 ...      ...
# 119  St Lukes Roosevelt Hospital - St Lukes Hospita...        1
# 120  St Lukes Roosevelt Hospital Center - Roosevelt...        0
# 121                                 St Peters Hospital        0
# 122              St. Luke's Cornwall Hospital/Cornwall        0
# 123                              St. Mary's Healthcare        0
# 124                Staten Island University Hosp-North        1
# 125                Staten Island University Hosp-South        1
# 126                           Strong Memorial Hospital        1
# 127                                   Syosset Hospital        0
# 128                    The Unity Hospital of Rochester        0
# 129  The University of Vermont Health Network - Cha...        0
# 130   UPSTATE University Hospital at Community General        0
# 131  United Health Services Hospitals Inc. - Bingha...        0
# 132  United Health Services Hospitals Inc. - Wilson...        0
# 133  United Memorial Medical Center North Street Ca...        0
# 134                                University Hospital        1
# 135     University Hospital SUNY Health Science Center        1
# 136                    University Hospital of Brooklyn        1
# 137                     Vassar Brothers Medical Center        0
# 138                         Westchester Medical Center        1
# 139                       White Plains Hospital Center        0
# 140                       Winthrop-University Hospital        1
# 141                      Woman's Christian Association        0
# 142            Woodhull Medical & Mental Health Center        0
# 143                     Wyckoff Heights Medical Center        0
# 144                       White Plains Hospital Center        0
# 145                       Winthrop-University Hospital        0
# 146                      Woman's Christian Association        0
# 147            Woodhull Medical & Mental Health Center        0
# 148                     Wyckoff Heights Medical Center        0
#
# [148 rows x 2 columns]
